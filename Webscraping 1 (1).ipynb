# %% [markdown]
# # WEB SCRAPING ASSIGNMENT

# %% [markdown]
# 1) Write a python program to display all the header tags from wikipedia.org and make data frame.

# %%
# !pip install bs4
# !pip install requests
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=2ddf55d2422b2a7e8df7eddc74a19b95d893d4192066f0c15ce0e4db3f1b7eac
#   Stored in directory: c:\users\viv\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.wikipedia.org"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')
headers = soup.find_all(['h1','h2','h3','h4','h5','h6'])

# %%
for header in headers:
    print (header.text)
# Out:
# Wikipedia
#
# The Free Encyclopedia
#
#
#
#
#
# 1 000 000+
#
#
# articles
#
#
#
#
#
#
#
#
# 100 000+
#
#
# articles
#
#
#
#
#
#
#
#
# 10 000+
#
#
# articles
#
#
#
#
#
#
#
#
# 1 000+
#
#
# articles
#
#
#
#
#
#
#
#
# 100+
#
#
# articles

# %%
df= pd.DataFrame({"Headers":headers})

# %%
df
# Out:
#                                              Headers
# 0  [\n, [\nWikipedia\n], \n, [The Free Encycloped...
# 1  [\n, [\n, [\n, <bdi dir="ltr">\n1 000 000+\n</...
# 2  [\n, [\n, [\n, <bdi dir="ltr">\n100 000+\n</bd...
# 3  [\n, [\n, [\n, <bdi dir="ltr">\n10 000+\n</bdi...
# 4  [\n, [\n, [\n, <bdi dir="ltr">\n1 000+\n</bdi>...
# 5  [\n, [\n, [\n, <bdi dir="ltr">\n100+\n</bdi>, ...

# %% [markdown]
# 2) Write s python program to display list of respected former presidents of India(i.e. Name , Term ofoffice)
# from https://presidentofindia.nic.in/former-presidents.htm and make data frame.

# %%
response = requests.get('https://presidentofindia.nic.in/former-presidents')
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <noscript><meta content="0; URL=/big_pipe/no-js?destination=/former-presidents" http-equiv="Refresh"/>
# </noscript><link href="/manifest.json" rel="manifest"/>
# <meta content="" name="theme-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="President of India" name="apple-mobile-web-app-title"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="" rel="apple-touch-icon" sizes="192x192"/>
# <link href="/iphone5_splash.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
# ...

# %%
Names = []
for i in soup.find_all('div',class_="desc-sec"):
    Names.append(i.text.replace("\n",''))
    
Names
#print(len(Names))
# Out:
# ['Shri Ram Nath Kovind14th President of India',
#  'Shri Pranab Mukherjee13th President of India',
#  'Smt Pratibha Devisingh Patil12th President of India',
#  'DR. A.P.J. Abdul Kalam11th President of India',
#  'Shri K. R. Narayanan10th President of India',
#  'Dr Shankar Dayal Sharma9th  President of India',
#  'Shri R Venkataraman8th President of India',
#  'Giani Zail Singh7th President of India',
#  'Shri Neelam Sanjiva Reddy6th President of India',
#  'Dr. Fakhruddin Ali Ahmed5th President of India',
#  'Shri Varahagiri Venkata Giri4th President of India',
#  'Dr. Zakir Husain3rd President of India',
#  'Dr. Sarvepalli Radhakrishnan2nd President of India',
#  'Dr. Rajendra Prasad1st President of India']

# %%
terms = []
for i in soupterm.select("h5"):
    terms.append(i.text)
terms

#print(len(terms))
# Out:
# ['Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  'Former President of India',
#  '14th Former President of India',
#  '13th Former President of India',
#  '12th President of India',
#  '',
#  '10th Former President of India',
#  '',
#  '8th Former President of India',
#  '7th Former President of India',
#  '6th Former President of India',
#  '5th Former President of India',
#  '',
#  '3th Former President of India',
#  '2th Former President of India']

# %%
df=pd.DataFrame({"Former Presidents":Names})
df
# Out:
#                                     Former Presidents
# 0         Shri Ram Nath Kovind14th President of India
# 1        Shri Pranab Mukherjee13th President of India
# 2   Smt Pratibha Devisingh Patil12th President of ...
# 3       DR. A.P.J. Abdul Kalam11th President of India
# 4         Shri K. R. Narayanan10th President of India
# 5      Dr Shankar Dayal Sharma9th  President of India
# 6           Shri R Venkataraman8th President of India
# 7              Giani Zail Singh7th President of India
# 8     Shri Neelam Sanjiva Reddy6th President of India
# 9      Dr. Fakhruddin Ali Ahmed5th President of India
# 10  Shri Varahagiri Venkata Giri4th President of I...
# 11             Dr. Zakir Husain3rd President of India
# 12  Dr. Sarvepalli Radhakrishnan2nd President of I...
# 13          Dr. Rajendra Prasad1st President of India

# %% [markdown]
# 3.Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data framea) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
soup = BeautifulSoup(response.content)



teams = []

for row in rows[1:11]:
    names = row.find("span",class_="u-hide-phablet").text.strip()
    matches = row.find_all("td")[2].text.strip()
    points = row.find_all("td")[3].text.strip()
    rating = row.find_all("td")[4].text.strip()
    teams.append((names,matches,points,rating))
    
teams 

df = pd.DataFrame(teams,columns = ["Teams","Matches", "Points", "Rating"])
df
# Out:
#           Teams Matches Points Rating
# 0         India      49  5,839    119
# 1     Australia      36  4,015    112
# 2      Pakistan      32  3,525    110
# 3  South Africa      29  3,166    109
# 4   New Zealand      38  4,007    105
# 5       England      34  3,377     99
# 6     Sri Lanka      43  3,943     92
# 7    Bangladesh      40  3,574     89
# 8   Afghanistan      26  2,170     83
# 9   West Indies      38  2,582     68

# %% [markdown]
# b) Top 10 ODI Batsmen along with the records of their team andrating

# %%
responseb = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
soupb = BeautifulSoup(responseb.content)
soupb.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\nICC Men's ODI Batting | Player Rankings | ICC\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInternational Cricket Council\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nName Lastname\n\n\n                        Profile % Complete\n                    \n\n\n\n\n\n\n\n\n\n\n\nFirst name *\n\n\n\n\nLast name *\n\n\n\n\n\n\nEmail address *\n\n\nEmail address not available.\n\n\nChange Email\n\n\n\n\nPassword *\n\n\n\n\nChange Password\n\n\n\nDate of Birth\n\n\nDay *\n\n\n\n\nMonth *\n\n\n\n\nYear *\n\n\n\n\nThe date of birth is not valid\n\n\nCountry of residence\n\n\n\n\n\n\n\n\nYour favourite team\n\n\n\n\n\nSorry, but your contact preferences will take up to 24hrs to update\n\n\n\n\n\nI'm happy for the ICC to contact me\n\n\n\n\n\n\nI'm happy for the ICC's partners to contact me\n\n\n\n\n\n\n\n\n    Hold on! Loading your preferences \n\n\n\n\nCancel\nSave Changes\n\n\nSign Out\n\n\n\n\n\n\n\n            Edit your password\n            back\n\n\nShow\nCurrent Passw
# ...

# %%
Batsmen = []

BatsmenData = soupb.find("table", class_="table")
rows = BatsmenData.find_all("tr")

for row in rows[1:11]:
    names = row.find("a").text.strip()
    team = row.find_all("td")[2].text.strip()
    rating = row.find_all("td")[3].text.strip()
    Batsmen.append((names,team,rating))
    
Batsmen

df= pd.DataFrame(Batsmen, columns=["Names","Team","Rating"])
df
# Out:
#                    Names Team Rating
# 0                         PAK    818
# 1           Shubman Gill  IND    816
# 2        Quinton de Kock   SA    765
# 3           David Warner  AUS    761
# 4           Rohit Sharma  IND    743
# 5       Heinrich Klaasen   SA    741
# 6            Virat Kohli  IND    735
# 7           Harry Tector  IRE    729
# 8  Rassie van der Dussen   SA    706
# 9            Dawid Malan  ENG    695

# %% [markdown]
# c) Top 10 ODI bowlers along with the records of their team andrating.

# %%
response = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
soup=BeautifulSoup(response.content)
soupc= soup.text

# %%
Bowlers = []
BowlersTable = soup.find("table",class_="table")
rows3 = BowlersTable.find_all("tr")

for row in rows3[1:11]:
    names= row.find("a").text.strip()
    teams= row.find_all("td")[2].text.strip()
    rating= row.find_all("td")[3].text.strip()
    Bowlers.append((names,teams,rating))
    
Bowlers
# Out:
# [('', 'PAK', '673'),
#  ('Josh Hazlewood', 'AUS', '663'),
#  ('Mohammed Siraj', 'IND', '656'),
#  ('Keshav Maharaj', 'SA', '651'),
#  ('Trent Boult', 'NZ', '649'),
#  ('Rashid Khan', 'AFG', '648'),
#  ('Kuldeep Yadav', 'IND', '646'),
#  ('Mujeeb Ur Rahman', 'AFG', '641'),
#  ('Adam Zampa', 'AUS', '637'),
#  ('Mohammad Nabi', 'AFG', '631')]

# %%
df= pd.DataFrame(Bowlers, columns = ["Bowlers", "Team", "Rating"])
df
# Out:
#             Bowlers Team Rating
# 0                    PAK    673
# 1    Josh Hazlewood  AUS    663
# 2    Mohammed Siraj  IND    656
# 3    Keshav Maharaj   SA    651
# 4       Trent Boult   NZ    649
# 5       Rashid Khan  AFG    648
# 6     Kuldeep Yadav  IND    646
# 7  Mujeeb Ur Rahman  AFG    641
# 8        Adam Zampa  AUS    637
# 9     Mohammad Nabi  AFG    631

# %% [markdown]
# 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data framea) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
response = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
soup = BeautifulSoup(response.content)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\nICC Women's ODI Team Rankings | ICC\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInternational Cricket Council\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nName Lastname\n\n\n                        Profile % Complete\n                    \n\n\n\n\n\n\n\n\n\n\n\nFirst name *\n\n\n\n\nLast name *\n\n\n\n\n\n\nEmail address *\n\n\nEmail address not available.\n\n\nChange Email\n\n\n\n\nPassword *\n\n\n\n\nChange Password\n\n\n\nDate of Birth\n\n\nDay *\n\n\n\n\nMonth *\n\n\n\n\nYear *\n\n\n\n\nThe date of birth is not valid\n\n\nCountry of residence\n\n\n\n\n\n\n\n\nYour favourite team\n\n\n\n\n\nSorry, but your contact preferences will take up to 24hrs to update\n\n\n\n\n\nI'm happy for the ICC to contact me\n\n\n\n\n\n\nI'm happy for the ICC's partners to contact me\n\n\n\n\n\n\n\n\n    Hold on! Loading your preferences \n\n\n\n\nCancel\nSave Changes\n\n\nSign Out\n\n\n\n\n\n\n\n            Edit your password\n            back\n\n\nShow\nCurrent Password *\n\n\
# ...

# %%
WTeams = []

Team_table = soup.find("table",class_="table")
rows = Team_table.find_all("tr")

for row in rows[1:11]:
    names = row.find("span",class_="u-hide-phablet").text.strip()
    matches = row.find_all("td")[2].text.strip()
    points= row.find_all("td")[3].text.strip()
    rating = row.find_all("td")[4].text.strip()
    WTeams.append((names,matches,points,rating))
    
#WTeams
df = pd.DataFrame(WTeams, columns = ["Teams", "Matches", "Points", "Rating"])
df
# Out:
#           Teams Matches Points Rating
# 0     Australia      19  3,084    162
# 1       England      23  2,991    130
# 2  South Africa      21  2,446    116
# 3         India      18  1,745     97
# 4   New Zealand      21  2,014     96
# 5   West Indies      18  1,610     89
# 6     Sri Lanka       9    714     79
# 7    Bangladesh      11    816     74
# 8      Thailand      11    753     68
# 9      Pakistan      21  1,435     68

# %% [markdown]
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.

# %%
responseb = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")
soupb = BeautifulSoup(response.content)
soupb.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\nICC Women's ODI Batting | Player Rankings | ICC\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInternational Cricket Council\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nName Lastname\n\n\n                        Profile % Complete\n                    \n\n\n\n\n\n\n\n\n\n\n\nFirst name *\n\n\n\n\nLast name *\n\n\n\n\n\n\nEmail address *\n\n\nEmail address not available.\n\n\nChange Email\n\n\n\n\nPassword *\n\n\n\n\nChange Password\n\n\n\nDate of Birth\n\n\nDay *\n\n\n\n\nMonth *\n\n\n\n\nYear *\n\n\n\n\nThe date of birth is not valid\n\n\nCountry of residence\n\n\n\n\n\n\n\n\nYour favourite team\n\n\n\n\n\nSorry, but your contact preferences will take up to 24hrs to update\n\n\n\n\n\nI'm happy for the ICC to contact me\n\n\n\n\n\n\nI'm happy for the ICC's partners to contact me\n\n\n\n\n\n\n\n\n    Hold on! Loading your preferences \n\n\n\n\nCancel\nSave Changes\n\n\nSign Out\n\n\n\n\n\n\n\n            Edit your password\n            back\n\n\nShow\nCurrent Pas
# ...

# %%
WPlayers = []

WTable = soupb.find("table",class_="table")
Rowsb = WTable.find_all("tr")

for row in Rowsb[1:11]:
    names = row.find("a").text.strip()
    teams = row.find_all("td")[2].text.strip()
    ratings = row.find_all("td")[3].text.strip()
    WPlayers.append((names,teams,ratings))
    
WPlayers

df= pd.DataFrame(WPlayers, columns=["Players","Teams","Rating"])
df
# Out:
#                Players Teams Rating
# 0                        ENG    807
# 1          Beth Mooney   AUS    750
# 2  Chamari Athapaththu    SL    736
# 3      Laura Wolvaardt    SA    727
# 4      Smriti Mandhana   IND    708
# 5         Alyssa Healy   AUS    698
# 6         Ellyse Perry   AUS    697
# 7     Harmanpreet Kaur   IND    694
# 8          Meg Lanning   AUS    662
# 9       Marizanne Kapp    SA    642

# %% [markdown]
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
responsec = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
soupc = BeautifulSoup(responsec.content)
soupc.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\nICC Women's ODI All Rounder | Player Rankings | ICC\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInternational Cricket Council\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nName Lastname\n\n\n                        Profile % Complete\n                    \n\n\n\n\n\n\n\n\n\n\n\nFirst name *\n\n\n\n\nLast name *\n\n\n\n\n\n\nEmail address *\n\n\nEmail address not available.\n\n\nChange Email\n\n\n\n\nPassword *\n\n\n\n\nChange Password\n\n\n\nDate of Birth\n\n\nDay *\n\n\n\n\nMonth *\n\n\n\n\nYear *\n\n\n\n\nThe date of birth is not valid\n\n\nCountry of residence\n\n\n\n\n\n\n\n\nYour favourite team\n\n\n\n\n\nSorry, but your contact preferences will take up to 24hrs to update\n\n\n\n\n\nI'm happy for the ICC to contact me\n\n\n\n\n\n\nI'm happy for the ICC's partners to contact me\n\n\n\n\n\n\n\n\n    Hold on! Loading your preferences \n\n\n\n\nCancel\nSave Changes\n\n\nSign Out\n\n\n\n\n\n\n\n            Edit your password\n            back\n\n\nShow\nCurrent
# ...

# %%
WomenARs = []

ARTable = soupc.find("table", class_="table")
Rowsc = ARTable.find_all("tr")

for row in Rowsc[1:11]:
    names = row.find("a").text.strip()
    teams = row.find_all("td")[2].text.strip()
    rating = row.find_all("td")[3].text.strip()
    WomenARs.append((names,teams,rating))
    
WomenARs

df = pd.DataFrame(WomenARs, columns = ["All Rounder Players", "Teams", "Rating"])
df
# Out:
#     All Rounder Players Teams Rating
# 0                          SA    385
# 1      Ashleigh Gardner   AUS    377
# 2  Natalie Sciver-Brunt   ENG    360
# 3       Hayley Matthews    WI    358
# 4           Amelia Kerr    NZ    346
# 5         Deepti Sharma   IND    312
# 6          Ellyse Perry   AUS    282
# 7         Jess Jonassen   AUS    227
# 8         Sophie Devine    NZ    227
# 9              Nida Dar   PAK    224

# %% [markdown]
# 5) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world and
# make data frame
# 1. Headline

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup


response = requests.get("https://www.cnbc.com/2023/11/02/novo-nordisk-weight-loss-drug-wegovy-could-get-new-fda-approval-in-six-months.html")
soup5 = BeautifulSoup(response.content)
soup5
# Out:
# <!DOCTYPE html>
# ...

# %%
Headline = soup5.find("h1",class_="ArticleHeader-headline").text
Headline
# Out:
# 'Weight-loss drug Wegovy could get expanded FDA approval within six months, Novo Nordisk says'

# %% [markdown]
# b.Time

# %%
Time = soup5.find("time").text
Time
# Out:
# 'Published Thu, Nov 2 20238:24 AM EDT'

# %% [markdown]
# c.News Link

# %%
NewsLink = soup5.find("a",class_="ArticleHeader-eyebrow")
NewsLink
# Out:
# <a class="ArticleHeader-eyebrow" href="https://www.cnbc.com/pharmaceuticals/">Pharmaceuticals</a>

# %%
Frame = []

Frame.append((Headline,Time,NewsLink))
Frame
# Out:
# [('Weight-loss drug Wegovy could get expanded FDA approval within six months, Novo Nordisk says',
#   'Published Thu, Nov 2 20238:24 AM EDT',
#   <a class="ArticleHeader-eyebrow" href="https://www.cnbc.com/pharmaceuticals/">Pharmaceuticals</a>)]

# %%
df = pd.DataFrame(Frame,columns = ["Headline","Time","News Link"])
df
# Out:
#                                             Headline  \
# 0  Weight-loss drug Wegovy could get expanded FDA...
#
#                                    Time          News Link
# 0  Published Thu, Nov 2 20238:24 AM EDT  [Pharmaceuticals]

# %% [markdown]
# 6.6) Write a python program to scrape the details of most downloaded articles from AI in last 90
# days.https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape below mentioned details and make data framei) Paper Title
# ii) Authors
# iii) Published Date
# iv) Paper URL

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

response6 = requests.get("https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles")
response6
# Out:
# <Response [200]>

# %%
soup6 = BeautifulSoup(response6.content)
soup6
# Out:
# <!DOCTYPE html>
# ...

# %%
Title = []

for i in soup6.find_all("h2",class_="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg"):
    Title.append(i.text)

Title
    
Authors = []

for i in soup6.find_all("span",class_="sc-1w3fpd7-0 dnCnAO"):
    Authors.append(i.text)
Authors
                          
date = []
for i in soup6.find_all("span",class_="sc-1thf9ly-2 dvggWt"):
    date.append(i.text)
date

url = []

for i in soup6.find_all("a",class_="sc-5smygv-0 fIXTHm"):
    url.append(i.text)
url
# Out:
# ['Reward is enough',
#  'Explanation in artificial intelligence: Insights from the social sciences',
#  'Creativity and artificial intelligence',
#  'Conflict-based search for optimal multi-agent pathfinding',
#  'Knowledge graphs as tools for explainable machine learning: A survey',
#  'Law and logic: A review from an argumentation perspective',
#  'Between MDPs and semi-MDPs: A framework for temporal abstraction in reinforcement learning',
#  'Explaining individual predictions when features are dependent: More accurate approximations to Shapley values',
#  'Multiple object tracking: A literature review',
#  'A survey of inverse reinforcement learning: Challenges, methods and progress',
#  'Evaluating XAI: A comparison of rule-based and example-based explanations',
#  'Explainable AI tools for legal reasoning about cases: A study on the European Court of Human Rights',
#  'Hard choices in artificial intelligence',
# ...

# %%
df = pd.DataFrame({"Title": Title, "Authors": Authors, "P.Date": date,"url":url})
df
# Out:
#                                                 Title  \
# 0                                    Reward is enough
# 1   Explanation in artificial intelligence: Insigh...
# 2              Creativity and artificial intelligence
# 3   Conflict-based search for optimal multi-agent ...
# 4   Knowledge graphs as tools for explainable mach...
# 5   Law and logic: A review from an argumentation ...
# 6   Between MDPs and semi-MDPs: A framework for te...
# 7   Explaining individual predictions when feature...
# 8       Multiple object tracking: A literature review
# 9   A survey of inverse reinforcement learning: Ch...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11  Explainable AI tools for legal reasoning about...
# 12            Hard choices in artificial intelligence
# 13  Assessing the communication gap between AI mod...
# 14  Explaining black-box classifiers using post-ho...
# 15  The Hanabi challenge: A new frontier for AI re...
# ...

# %% [markdown]
# 7) Write a python program to scrape mentioned details from dineout.co.inand make data framei) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image UR

# %%
response7 = requests.get("https://dineout.co.in")
response7
# Out:
# <Response [200]>

# %% [markdown]
# The website isn't opening in my region. I have tried a lot with Ip adressing too.
